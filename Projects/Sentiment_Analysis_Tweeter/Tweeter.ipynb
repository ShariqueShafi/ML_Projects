# %% [markdown]
# AAAAAAAAAAAAAAAAAAAAANuQ7AEAAAAAaAaySsMfk6gdGIiFRR49X08BbMY%3De1ojcUX8yiukzFTJkimTrit9RJ2LKOvQFrFwu6THaBxSKvDISa

# %%
# !pip install -U tweepy

# %%
# !pip install tweepy

# %%
import tweepy
import pandas as pd

BEARER_TOKEN="AAAAAAAAAAAAAAAAAAAAANuQ7AEAAAAAaAaySsMfk6gdGIiFRR49X08BbMY%3De1ojcUX8yiukzFTJkimTrit9RJ2LKOvQFrFwu6THaBxSKvDISa"
clint = tweepy.Client(bearer_token=BEARER_TOKEN, wait_on_rate_limit=True)
query="#ClothBank"
max_result = 10
response = clint.search_recent_tweets(query=query, max_results=max_result, tweet_fields=["created_at","lang","public_metrics","author_id", "source"])

if response.data is None:
  tweet_df = pd.DataFrame()
else:
  tweet_df = pd.DataFrame([
      {
          "id":tweet.id,
          "text":tweet.text,
          "created_at":tweet.created_at,
          "lang":tweet.lang,
          "retweet_count":tweet.public_metrics["retweet_count"],
          "like_count":tweet.public_metrics["like_count"],
          "reply_count":tweet.public_metrics["reply_count"],
          "quote_count":tweet.public_metrics["quote_count"]
      }
      for tweet in response.data
  ])
tweets_df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# /tmp/ipython-input-175039727.py in <cell line: 0>()
#       6 query="#ClothBank"
#       7 max_result = 10
# ----> 8 response = clint.search_recent_tweets(query=query, max_results=max_result, tweet_fields=["created_at","lang","public_metrics","author_id", "source"])
#       9
#      10 if response.data is None:
#
# /usr/local/lib/python3.12/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1274         """
#    1275         params["query"] = query
# -> 1276         return self._make_request(
#    1277             "GET", "/2/tweets/search/recent", params=params,
#    1278             endpoint_parameters=(
#
# /usr/local/lib/python3.12/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
# ...

# %%
import tweepy
import pandas as pd

# Bearer Token from X docs example (FAKE token; replace with your own real token)
BEARER_TOKEN = (
    "AAAAAAAAAAAAAAAAAAAAANuQ7AEAAAAAk2X0uBjybPu2dRfMjdhm6SicMZE%3DZZRDn7UN4sFGgOPhmXZDQBkqmn6bJWwqWlayXk4wIccWncErV5"
)

# App-only authentication using OAuth 2.0 Bearer Token
client = tweepy.Client(
    bearer_token=BEARER_TOKEN,
    wait_on_rate_limit=True
)

query = "#ClothBank"
max_results = 10

response = client.search_recent_tweets(
    query=query,
    max_results=max_results,
    tweet_fields=["created_at", "lang", "public_metrics", "author_id", "source"]
)

if response.data is None:
    tweets_df = pd.DataFrame()
else:
    tweets_df = pd.DataFrame(
        [
            {
                "id": tweet.id,
                "text": tweet.text,
                "created_at": tweet.created_at,
                "lang": tweet.lang,
                "retweet_count": tweet.public_metrics["retweet_count"],
                "like_count": tweet.public_metrics["like_count"],
                "reply_count": tweet.public_metrics["reply_count"],
                "quote_count": tweet.public_metrics["quote_count"],
            }
            for tweet in response.data
        ]
    )

tweets_df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# /tmp/ipython-input-3522111932.py in <cell line: 0>()
#      16 max_results = 10
#      17
# ---> 18 response = client.search_recent_tweets(
#      19     query=query,
#      20     max_results=max_results,
#
# /usr/local/lib/python3.12/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1274         """
#    1275         params["query"] = query
# -> 1276         return self._make_request(
#    1277             "GET", "/2/tweets/search/recent", params=params,
#    1278             endpoint_parameters=(
#
# /usr/local/lib/python3.12/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     127         request_params = self._process_params(params, endpoint_parameters)
#     128
# ...
